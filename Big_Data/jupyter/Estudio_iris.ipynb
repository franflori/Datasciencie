# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../datos/Iris2.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
len(df)
# Out:
# 150

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe(include="all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %% [markdown]
#  + Existen columnas con "missing values" (valores que faltan)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Para el pétalo
sns.FacetGrid(df, hue="Species", height=6.4) \
.map(plt.scatter, "PetalLengthCm", "PetalWidthCm") \
.add_legend()
plt.title("Gráfica para el pétalo - con Seaborn")
plt.show()

# %% [markdown]
# *Conclusiones*
#  - Se obserba como en el caso de sestosa esta bien separada de las dos clases
#  - En el caso virginica y versicola esta los datos entre 4.5 y5.5   y la anchora de 1.5 se mezclan alguns dato de flores

# %%
# para el sépalo
sns.FacetGrid(df, hue="Species", height = 6.4) \
.map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
.add_legend() \
.set(title="Gráfica para el sépalo - con Seaborn")
# plt.title("Species en función del largo y ancho del sépalo")
plt.show()

# %% [markdown]
# *Conclusiones*
#  - Se obserba como en el caso de sestosa esta bien separada de las dos clases
#  - En el caso virginica y versicola esta los datos entre mezclado y es dificil distinguirlo

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# boxplot
df.boxplot(column=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"])
# Out:
# <AxesSubplot:>

# %%
# Filtrar por cada uno de los tipos
setosa = df[df["Species"] == "Iris-setosa"]
setosa.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# boxplot para setosa
setosa.boxplot(column=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"])
# Out:
# <AxesSubplot:>

# %%
# Filtrar por cada uno de los tipos
versicolor = df[df["Species"] == "Iris-versicolor"]
versicolor.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
#
#             Species
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor

# %%
# boxplot para setosa
versicolor.boxplot(column=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"])
# Out:
# <AxesSubplot:>

# %%
 # Filtrar por cada uno de los tipos
virginica = df[df["Species"] == "Iris-virginica"]
virginica.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
#
#             Species
# 100  Iris-virginica
# 101  Iris-virginica
# 102  Iris-virginica
# 103  Iris-virginica
# 104  Iris-virginica

# %%
# boxplot para setosa
virginica.boxplot(column=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,20))
plt.subplot(3, 3, 1)
setosa.boxplot(column=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"])
plt.subplot(3, 3, 2)
versicolor.boxplot(column=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"])
plt.subplot(3, 3, 3)
virginica.boxplot(column=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"])
plt.show()

# %%
def graph(y):
    sns.boxplot(x="Species", y=y, data=df)
    plt.figure(figsize=(10,10))
    # Adding the subplot at the specified
    # grid position
plt.subplot(221)
graph('SepalLengthCm')
plt.subplot(222)
graph('SepalWidthCm')
plt.subplot(223)
graph('PetalLengthCm')
plt.subplot(224)
graph('PetalWidthCm')
plt.show()

# %% [markdown]
# *Conclusiones*
#
#     - Observamos que en el caso del Sépalo en virgínica presenta outliers, mientras que en las otras dos especies no.
#     - En el caso del Pétalo setosa y versicolor presentan outliers para la longitud del pétalo, y en el caso de setosa también para la anchura
#     - en el caso de setosa el tamaño del pétalo y también en la longitud del sépalo presenta menor tamaño que las otras dos especies. Yla variabilidad de los datos también es menor en estos casos. Mientras que en la anchura del sépalo la variabilidad es mucho mayor que el de las otras dos especies.

# %% [markdown]
# ## Histrograma
#
# # SepalLengthCm

# %%
plt.figure(figsize=(20,20))
df.groupby("Species").SepalLengthCm.value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# # SepalWidthCm

# %%
plt.figure(figsize=(20,20))
df.groupby("Species").SepalWidthCm.value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# ## PetalLengthCm

# %%
plt.figure(figsize=(20,20))
df.groupby("Species").PetalLengthCm.value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# ## PetalWidthhCm

# %%
plt.figure(figsize=(20,20))
df.groupby("Species").PetalWidthCm.value_counts().plot(kind="bar")
plt.show()

# %%
plot = sns.FacetGrid(df, hue="Species")
plot.map(sns.distplot, "SepalLengthCm").add_legend()
plot = sns.FacetGrid(df, hue="Species")
plot.map(sns.distplot, "SepalWidthCm").add_legend()
plot = sns.FacetGrid(df, hue="Species")
plot.map(sns.distplot, "PetalLengthCm").add_legend()
plot = sns.FacetGrid(df, hue="Species")
plot.map(sns.distplot, "PetalWidthCm").add_legend()
plt.show()
# Out:
# c:\users\fjflorido\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\users\fjflorido\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # Violin plot
#     - Pétal

# %%
sns.set(font_scale=1.8, rc={'figure.figsize':(12, 10)})
sns.violinplot(x="Species", y="PetalLengthCm", data=df, size=6)
plt.show()

# %%
sns.set(font_scale=1.8, rc={'figure.figsize':(12, 10)})
sns.violinplot(x="Species", y="PetalWidthCm", data=df, size=6)
plt.show()

# %% [markdown]
# *Conclusiones*
#     - En el caso, de víginica presenta más variabilidad de los datos y estan más homogéneos, que en caso sobretodo de setosa que sería lo opuesto.
#
#
# *- Sepal*

# %%
sns.set(font_scale=1.8, rc={'figure.figsize':(12, 10)})
sns.violinplot(x="Species", y="SepalLengthCm", data=df, size=6)
plt.show()

# %%
sns.set(font_scale=1.8, rc={'figure.figsize':(12, 10)})
sns.violinplot(x="Species", y="PetalWidthCm", data=df, size=6)
plt.show()

# %% [markdown]
# *Concluisiones*
#     - En el caso de la longitud en virgínica presenta más varaibaildad pero en anchra es en setosa, los valores se encuntra conetradso en ambas especies

# %%
sns.pairplot(df.drop(['Id'], axis = 1),hue='Species')

# %%
sns.heatmap(df.corr(method='pearson').drop(
['Id'], axis=1).drop(['Id'], axis=0),
annot = True);
plt.show()
