# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pip install nltk
# Out:
# ...
#      ---------------------------------------- 1.5/1.5 MB 13.6 MB/s eta 0:00:00
# ...
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# ...
#      -------------------------------------- 267.7/267.7 kB 8.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

# %%
# nltk.download()
nltk.download("gutenberg")
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\fran\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\gutenberg.zip.
# True

# %%
nltk.download("genesis")
# Out:
# [nltk_data] Downloading package genesis to
# [nltk_data]     C:\Users\fran\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\genesis.zip.
# True

# %%
nltk.download("inaugural")
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\fran\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\inaugural.zip.
# True

# %%
nltk.download("nps_chat")
# Out:
# [nltk_data] Downloading package nps_chat to
# [nltk_data]     C:\Users\fran\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\nps_chat.zip.
# True

# %%
nltk.download('webtext')
# Out:
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\fran\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\webtext.zip.
# True

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\fran\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# True

# %% [markdown]
#  # 1 Ejemplo

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
print(text1)
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
len(text1)
# Out:
# 260819

# %%
type(text1)
# Out:
# nltk.text.Text

# %% [markdown]
# # 1.1 Frecuencia de palabras en un texto

# %% [markdown]
# Palabras con mayo frecuencia.

# %% [markdown]
# Podría ayudar a distinguir autores por su forma de escribir.

# %%
dist1 = FreqDist(text1)
dist1
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
dist1[","]
# Out:
# 18713

# %%
dist1["whale"]
# Out:
# 906

# %%
dist1.plot(25)
plt.show()

# %%
dist1.plot(5)
plt.show()

# %% [markdown]
# Vemos que hay palabras que no aportan mucha información

# %% [markdown]
# # 1.2 Stopwords

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fran\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
sw = stopwords.words("spanish")
sw
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
# ...

# %%
stopwords = stopwords.words("english")
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
len(stopwords)
# Out:
# 179

# %% [markdown]
#  # 1.3 Signos puntuación

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
type(string.punctuation)
# Out:
# str

# %%
signos_puntuacion = list(string.punctuation)
print(signos_puntuacion)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %%
len(signos_puntuacion)
# Out:
# 32

# %% [markdown]
#  # 1.4 Palabras a eliminar

# %%
palabras_eliminar = stopwords + signos_puntuacion
palabras_eliminar
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
len(text1), len(palabras_eliminar)
# Out:
# (260819, 211)

# %% [markdown]
# Palabras importantes, en este caso solo sumo cuantas hay

# %%
palabrasImportantes = 0
for palabra in text1:
    if palabra not in palabras_eliminar:
        palabrasImportantes += 1
palabrasImportantes
# Out:
# 122531

# %% [markdown]
# Palabras Importantes, aqui me creo la lista con ellas

# %%
palabrasImportantesDB = []
for palabra in text1:
    if palabra not in palabras_eliminar:
        palabrasImportantesDB.append(palabra)
palabrasImportantesDB
# Out:
# ['Moby',
#  'Dick',
#  'Herman',
#  'Melville',
#  '1851',
#  'ETYMOLOGY',
#  'Supplied',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'Grammar',
#  'School',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'coat',
#  'heart',
#  'body',
#  'brain',
#  'I',
#  'see',
#  'He',
#  'ever',
#  'dusting',
#  'old',
#  'lexicons',
#  'grammars',
#  'queer',
#  'handkerchief',
#  'mockingly',
#  'embellished',
#  'gay',
#  'flags',
#  'known',
#  'nations',
#  'world',
#  'He',
#  'loved',
#  'dust',
#  'old',
#  'grammars',
#  'somehow',
#  'mildly',
#  'reminded',
#  'mortality',
#  'While',
#  'take',
#  'hand',
#  'school',
#  'others',
#  'teach',
#  'name',
#  'whale',
#  'fish',
#  'called',
#  'tongue',
#  'leaving',
#  'ignorance',
#  'letter',
#  'H',
#  'almost',
#  'alone',
#  'maketh',
#  'signification',
#  'word',
#  'deliver',
#  'true',
#  '."',
#  '--',
#  'HACKLUYT',
#  'WHALE',
#  '...',
#  'Sw',
#  'Dan',
#  'HVAL',
#  'This',
#  'animal',
#  'named',
# ...

# %%
len(palabrasImportantesDB), len(text1)
# Out:
# (122531, 260819)

# %% [markdown]
# Recordando la forma rápida de Python

# %%
palabras_imp = []
[palabras_imp.append(palabra) for palabra in text1 if palabra not in palabras_eliminar]
palabras_imp
# Out:
# ['Moby',
#  'Dick',
#  'Herman',
#  'Melville',
#  '1851',
#  'ETYMOLOGY',
#  'Supplied',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'Grammar',
#  'School',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'coat',
#  'heart',
#  'body',
#  'brain',
#  'I',
#  'see',
#  'He',
#  'ever',
#  'dusting',
#  'old',
#  'lexicons',
#  'grammars',
#  'queer',
#  'handkerchief',
#  'mockingly',
#  'embellished',
#  'gay',
#  'flags',
#  'known',
#  'nations',
#  'world',
#  'He',
#  'loved',
#  'dust',
#  'old',
#  'grammars',
#  'somehow',
#  'mildly',
#  'reminded',
#  'mortality',
#  'While',
#  'take',
#  'hand',
#  'school',
#  'others',
#  'teach',
#  'name',
#  'whale',
#  'fish',
#  'called',
#  'tongue',
#  'leaving',
#  'ignorance',
#  'letter',
#  'H',
#  'almost',
#  'alone',
#  'maketh',
#  'signification',
#  'word',
#  'deliver',
#  'true',
#  '."',
#  '--',
#  'HACKLUYT',
#  'WHALE',
#  '...',
#  'Sw',
#  'Dan',
#  'HVAL',
#  'This',
#  'animal',
#  'named',
# ...

# %% [markdown]
# # 2.1 Counter

# %%
dist2 = FreqDist(palabras_imp)
dist2
# Out:
# FreqDist({'I': 2124, '--': 1070, 'whale': 906, 'one': 889, 'But': 705, 'like': 624, 'The': 612, 'upon': 538, 'man': 508, 'ship': 507, ...})

# %%
dist2.plot(10)
plt.show()

# %% [markdown]
# Vamos a calcular con Counter

# %%
from collections import Counter

# %%
contadorPalabras = Counter(palabras_imp)
contadorPalabras
# Out:
# Counter({'Moby': 84,
#          'Dick': 84,
#          'Herman': 1,
#          'Melville': 1,
#          '1851': 3,
#          'ETYMOLOGY': 1,
#          'Supplied': 2,
#          'Late': 1,
#          'Consumptive': 1,
#          'Usher': 2,
#          'Grammar': 2,
#          'School': 1,
#          'The': 612,
#          'pale': 18,
#          '--': 1070,
#          'threadbare': 1,
#          'coat': 28,
#          'heart': 90,
#          'body': 110,
#          'brain': 37,
#          'I': 2124,
#          'see': 253,
#          'He': 230,
#          'ever': 203,
#          'dusting': 2,
#          'old': 436,
#          'lexicons': 1,
#          'grammars': 2,
#          'queer': 44,
#          'handkerchief': 5,
#          'mockingly': 1,
#          'embellished': 3,
#          'gay': 13,
#          'flags': 1,
#          'known': 80,
#          'nations': 12,
#          'world': 173,
#          'loved': 3,
#          'dust': 10,
#          'somehow': 43,
# ...

# %% [markdown]
# Ordeno de Mayor a Menor transformando el diccionario en dataframe

# %%
listado_keys = []
for key in contadorPalabras.keys():
    listado_keys.append(key)
listado_keys
# Out:
# ['Moby',
#  'Dick',
#  'Herman',
#  'Melville',
#  '1851',
#  'ETYMOLOGY',
#  'Supplied',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'Grammar',
#  'School',
#  'The',
#  'pale',
#  '--',
#  'threadbare',
#  'coat',
#  'heart',
#  'body',
#  'brain',
#  'I',
#  'see',
#  'He',
#  'ever',
#  'dusting',
#  'old',
#  'lexicons',
#  'grammars',
#  'queer',
#  'handkerchief',
#  'mockingly',
#  'embellished',
#  'gay',
#  'flags',
#  'known',
#  'nations',
#  'world',
#  'loved',
#  'dust',
#  'somehow',
#  'mildly',
#  'reminded',
#  'mortality',
#  'While',
#  'take',
#  'hand',
#  'school',
#  'others',
#  'teach',
#  'name',
#  'whale',
#  'fish',
#  'called',
#  'tongue',
#  'leaving',
#  'ignorance',
#  'letter',
#  'H',
#  'almost',
#  'alone',
#  'maketh',
#  'signification',
#  'word',
#  'deliver',
#  'true',
#  '."',
#  'HACKLUYT',
#  'WHALE',
#  '...',
#  'Sw',
#  'Dan',
#  'HVAL',
#  'This',
#  'animal',
#  'named',
#  'roundness',
#  'rolling',
#  'HVALT',
#  'arched',
# ...

# %%
listado_values = []
for value in contadorPalabras.values():
    listado_values.append(value)
listado_values
# Out:
# [84,
#  84,
#  1,
#  1,
#  3,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  612,
#  18,
#  1070,
#  1,
#  28,
#  90,
#  110,
#  37,
#  2124,
#  253,
#  230,
#  203,
#  2,
#  436,
#  1,
#  2,
#  44,
#  5,
#  1,
#  3,
#  13,
#  1,
#  80,
#  12,
#  173,
#  3,
#  10,
#  43,
#  10,
#  4,
#  1,
#  30,
#  118,
#  205,
#  9,
#  37,
#  5,
#  69,
#  906,
#  133,
#  116,
#  11,
#  38,
#  10,
#  12,
#  2,
#  186,
#  37,
#  5,
#  1,
#  76,
#  3,
#  73,
#  489,
#  1,
#  38,
#  11,
#  1,
#  4,
#  1,
#  107,
#  16,
#  11,
#  1,
#  35,
#  2,
#  10,
#  2,
#  2,
#  63,
#  3,
#  310,
#  14,
#  1,
#  1,
#  1,
#  167,
#  1,
#  1,
#  16,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  1,
#  3,
#  1,
#  5,
#  1,
#  4,
#  2,
#  4,
#  1,
#  1,
#  2,
#  7,
#  1,
#  15,
#  161,
#  42,
#  1,
#  1,
#  1,
#  5,
#  106,
#  51,
#  7,
#  58,
#  318,
#  1,
#  10,
#  1,
#  46,
#  4,
#  44,
#  5,
#  7,
#  237,
#  215,
#  2,
#  55,
#  38,
#  5,
#  7,
#  4,
#  11,
#  282,
#  222,
# ...

# %%
import pandas as pd
df = pd.DataFrame({"Keys": listado_keys, "values": listado_values})
df.head()
# Out:
#        Keys  values
# 0      Moby      84
# 1      Dick      84
# 2    Herman       1
# 3  Melville       1
# 4      1851       3

# %%
df_mayor_menor = df.sort_values(by="values", ascending=False)
df_mayor_menor.head()
# Out:
#       Keys  values
# 20       I    2124
# 14      --    1070
# 50   whale     906
# 205    one     889
# 239    But     705

# %%
dist2
# Out:
# FreqDist({'I': 2124, '--': 1070, 'whale': 906, 'one': 889, 'But': 705, 'like': 624, 'The': 612, 'upon': 538, 'man': 508, 'ship': 507, ...})

# %%
contadorPalabras
# Out:
# Counter({'Moby': 84,
#          'Dick': 84,
#          'Herman': 1,
#          'Melville': 1,
#          '1851': 3,
#          'ETYMOLOGY': 1,
#          'Supplied': 2,
#          'Late': 1,
#          'Consumptive': 1,
#          'Usher': 2,
#          'Grammar': 2,
#          'School': 1,
#          'The': 612,
#          'pale': 18,
#          '--': 1070,
#          'threadbare': 1,
#          'coat': 28,
#          'heart': 90,
#          'body': 110,
#          'brain': 37,
#          'I': 2124,
#          'see': 253,
#          'He': 230,
#          'ever': 203,
#          'dusting': 2,
#          'old': 436,
#          'lexicons': 1,
#          'grammars': 2,
#          'queer': 44,
#          'handkerchief': 5,
#          'mockingly': 1,
#          'embellished': 3,
#          'gay': 13,
#          'flags': 1,
#          'known': 80,
#          'nations': 12,
#          'world': 173,
#          'loved': 3,
#          'dust': 10,
#          'somehow': 43,
# ...

# %% [markdown]
#    **Ploteamos los datos**

# %%
dist2.plot(5)
plt.show()

# %%
dist2.plot(25)
plt.show()

# %%
df_mayor_menor.head().plot(kind="bar")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.barplot(x="Keys", y="values", data=df_mayor_menor.head(25))
plt.show()
